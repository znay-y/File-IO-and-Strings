// %% [markdown]
// # Lab 9
// ## I/O, Strings & Regex: Essential Data Handling Techniques
//
// In this lab, you will practise reading from files, processing strings, and using regular expressions to validate and extract data.
//
// Deadline: **Week 12** in your respective lab session

// %% [markdown]
// ## Question 1 [0.75 marks] – Reading from a File
//
// Write a program that:
// - Reads a text file called `input.txt`
// - Prints each line to the console
//
// You must use `BufferedReader`.

// %%
  import java.io.BufferedReader;
import java.io.FileReader;
import java.io.IOException;


try (BufferedReader reader = new BufferedReader(new FileReader("text.txt"))) {
  String line;
  while ((line = reader.readLine()) != null) {
    System.out.println(line);
  }
} catch (IOException e) {
  System.out.println("Error reading file.");
}
// Out:
// First line
// Second line
// Third line

// %% [markdown]
// ## Question 2 [0.75 marks] – String Processing
//
// Write a method:
//
// `static int countWords(String line)`
//
// that returns the number of words in a given string.
//
// - Words are separated by spaces
// - Ignore leading/trailing spaces

// %%
// Write your code here
static int countWords(String line){
    String [] words= line.split(" ");
    return words.length;
}

System.out.println(countWords("The quick brown fox jumps over the lazy dog")); //9)
System.out.println(countWords("One"));//1
// Out:
// 9
// 1

// %% [markdown]
// ## Question 3 [0.75 marks] – Basic Regex Matching
//
// Write a method:
//
// `static boolean isValidEmail(String email)`
//
// that returns `true` if the input is a valid email and `false` otherwise.
//
// Use a regular expression.

// %%
// Write your code here
static boolean isValidEmail(String email){
        String regex = "^[A-Za-z0-9+_.-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}$";
        if (email.matches(regex)) {
            return true;
        } else {
            return false;
        }
    }

System.out.println(isValidEmail("somethit+345@gmail.com")); //true
System.out.println(isValidEmail("Notanemail.com"));//false
// Out:
// true
// false

// %% [markdown]
// ## Question 4 [0.75 marks] – Extracting Data with Regex
//
// Write a method:
//
// `static ArrayList<String> extractNumbers(String text)`
//
// that extracts all numbers from a string using regex and returns them as a list.

// %%
// Write your code here
static ArrayList<String> extractNumbers(String text) {
        ArrayList<String> Aaray = new ArrayList<String>();
        String regex = "^[0-9]";
        String[] letters = text.split("");

        for (int i = 0; i < letters.length; i++) {
            if (letters[i].matches(regex)) {
                Aaray.add(letters[i]);
            }
        }

        return Aaray;
    }

System.out.println(extractNumbers("3uo5bui4b35ih34ui5")); // [3, 5, 4, 3, 5, 3, 4, 5]
System.out.println(extractNumbers("123"));// [1, 2, 3]
System.out.println(extractNumbers("nonumbersinhere"));// []
// Out:
// [3, 5, 4, 3, 5, 3, 4, 5]
// [1, 2, 3]
// []

// %% [markdown]
// ## Question 5 [2 marks] – Mini Data Processing Task
//
// Write a program that:
//
// 1. Reads a file called `data.txt`
// 2. Each line has the format:
//
// `Name,Email,Age`
//
// Example:
//
// `Alice,alice@example.com,25`
//
// `Bob,invalid-email,30`
//
// `Charlie,charlie@mail.com,notanumber`
//
// Your program must:
// - Read each line
// - Split the data
// - Validate email using your method from Question 3
// - Ensure age is a valid integer
//
// Output only valid entries in the format:
//
// `Alice (25) - alice@example.com`

// %%
// Write your code here

        try (BufferedReader br = new BufferedReader(new FileReader("data.txt"))) {
            String line;
            while ((line = br.readLine()) != null) {
                boolean valid = checkLine(line);
                if (valid == true) {
                    System.out.println(printLine(line));
                }
            }
        } catch (FileNotFoundException e) {
            System.out.println("The given file cannot be found");
        } catch (IOException e) {
            System.out.println("Error reading file.");
        }
    

    static boolean checkLine(String input) {
        String[] parts = input.split(",");

        if (parts.length == 3) {
            //System.out.println("Name found: " + parts[0]);
            //System.out.println("E-mail found: " + parts[1]);
            //System.out.println("Age found: " + parts[2]);

            boolean isEmailValid = emailCheck(parts[1]);
            boolean isAgeValid = AgeCheck(parts[2]);

            if (isAgeValid==true&&isEmailValid==true){
                return true;
            }
        } else {
            //System.out.println("Input does NOT fit the format");
        }
        return false;

    }

    static boolean emailCheck(String email) {
        String regex = "^[A-Za-z0-9+_.-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}$";
        if (email.matches(regex)) {
            return true;
        } else {
            return false;
        }
    }

    static boolean AgeCheck(String text) {
        String regex = "^[0-9]";
        String[] letters = text.split("");

        for (int i = 0; i < letters.length; i++) {
            if (letters[i].matches(regex)) {
            
            } else {
                return false;
            }

        }
        return true;
    }

    static String printLine(String input) {
        String[] parts = input.split(",");

        String name = parts[0];
        String email = parts[1];
        String age = parts[2];


        return (name + " ("+age+") - "+email);
    }
// Out:
// Sophia Moore (42) - sophia.moore@yahoo.com
// Noah Lopez (34) - noah.lopez@hotmail.com
// Amelia Thomas (34) - amelia.thomas@yahoo.com
// James Thomas (42) - james.thomas@yahoo.com
// Harper Smith (42) - harper.smith@protonmail.com
// Sophia Johnson (56) - sophia.johnson@icloud.com
// Harper Gonzalez (44) - harper.gonzalez@gmail.com
// Mia Rodriguez (65) - mia.rodriguez@outlook.com
// Sophia Miller (62) - sophia.miller@protonmail.com
// Noah Taylor (40) - noah.taylor@gmail.com
// Evelyn Taylor (61) - evelyn.taylor@outlook.com
// Mia Martin (34) - mia.martin@hotmail.com
// Olivia Rodriguez (57) - olivia.rodriguez@gmail.com
// Harper Lopez (38) - harper.lopez@protonmail.com
// Elijah Anderson (71) - elijah.anderson@hotmail.com
// Oliver Rodriguez (44) - oliver.rodriguez@gmail.com
// Liam Lopez (55) - liam.lopez@outlook.com
// Abigail Davis (60) - abigail.davis@icloud.com
// Noah Brown (75) - noah.brown@gmail.com
// Amelia Miller (39) - amelia.miller@outlook.com
// ...
